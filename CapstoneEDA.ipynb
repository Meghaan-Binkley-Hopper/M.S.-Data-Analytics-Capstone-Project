# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
ipeds = pd.read_excel("IPEDSData_Transpose.xlsx") #read file
ipeds.set_index('Year', inplace = True) #set column index
print(ipeds)
# Out:
#       Harris-Stowe State University  Lincoln University  \
# Year
# 2022                            133                 252
# 2021                            115                 184
# 2020                             69                 230
# 2019                              0                 229
# 2018                            259                 288
# 2017                              0                 254
# 2016                            252                 304
# 2015                            199                 438
# 2014                            202                 373
# 2013                            168                 334
# 2012                            277                 353
#
#       Missouri Southern State University  \
# Year
# 2022                                 423
# 2021                                 444
# 2020                                 553
# 2019                                 542
# 2018                                 735
# ...

# %%
ipeds.dtypes #verify data types
# Out:
# Harris-Stowe State University                    int64
# Lincoln University                               int64
# Missouri Southern State University               int64
# Missouri State University-Springfield            int64
# Missouri University of Science and Technology    int64
# Missouri Western State University                int64
# Northwest Missouri State University              int64
# Southeast Missouri State University              int64
# Truman State University                          int64
# University of Central Missouri                   int64
# University of Missouri-Columbia                  int64
# University of Missouri-Kansas City               int64
# University of Missouri-St Louis                  int64
# dtype: object

# %%
ipeds.describe() #Finding descriptive statistics of data set
# Out:
#        Harris-Stowe State University  Lincoln University  \
# count                      11.000000           11.000000
# mean                      152.181818          294.454545
# std                        98.420342           74.817596
# min                         0.000000          184.000000
# 25%                        92.000000          241.000000
# 50%                       168.000000          288.000000
# 75%                       227.000000          343.500000
# max                       277.000000          438.000000
#
#        Missouri Southern State University  \
# count                           11.000000
# mean                           639.909091
# std                            131.253537
# min                            423.000000
# 25%                            547.500000
# 50%                            668.000000
# 75%                            737.500000
# max                            799.000000
#
#        Missouri State University-Springfield  \
# ...

# %%
#Create plot displaying enrollment for Northwest
ipeds["Northwest Missouri State University"].plot()
plt.title('Northwest Missouri State University Enrollment')
plt.ylabel('Enrollment Total')
plt.show()
